# %%
#1
#Remove string duplicates

class Solution:
	def removeDuplicates(self, s):
	    # code here
	    seen=set()
	    output=''
	    for i in s:
	        if i not in seen:
	            output+=i
	            seen.add(i)
	            
	    return output

# %%
#2
# Most frequent character in a string

class Solution:
    def getMaxOccurringChar(self, s):
        #code here
        dic={}

        for i in s:
            dic[i]=dic.get(i,0)+1

        max_val= max(dic.values())

        return min(k for k, v in dic.items() if v == max_val)
